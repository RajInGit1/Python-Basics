# %% [markdown]
# Write a Python program that takes a list of integers and finds the second largest element without using the built-in sort() or sorted() functions.

# %% [markdown]
# numbers = [5,3,9,2,6,4,8]
# largest = float('-inf')
# second_large = float('-inf')
#
# for num in numbers:
#     if num > largest:
#        second_large = largest
#        largest = num
#        elif num > second_largest and num != largest:
#         second_largest = num
#
# print("Second largest:", second_largest)
